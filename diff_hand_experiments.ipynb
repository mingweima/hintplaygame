# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import pickle
import glob
import os

# %%
models = ['FF', 'LSTM', 'Att1', 'Att2', 'Att3', ]
model_names = ['Feedforward', 'Recurrent', 'Att + O', 'Att + O + AO', 'Att + O + AI', ]

# %%
res_groups = {}
for model in models:
    print(model)
    path_res = f'res/{model}_hs_5_l1_3_l2_3_FalseFalse4000000'
    model_list = []
    for file in sorted(glob.glob(os.path.join(path_res, "*.pkl")))[0:]:
         with open(file, "rb") as f:
                model_list.append(pickle.load(f))
    res_groups[model] = model_list
# Out:
# FF
# LSTM
# Att1
# Att2
# Att3

# %%
xp_groups = {}

for model in models:
    print(model)
    path_res = f'sample/diff_hand/xp_{model}_diff.csv'
    xp_groups[model] = pd.read_csv(path_res, index_col=0)
# Out:
# FF
# LSTM
# Att1
# Att2
# Att3

# %% [markdown]
# ## Part 1: Learning curves

# %%
def ma(rewards, m=500):
    rewards = np.array(rewards)
    rewards = rewards.reshape(m,-1)
    moving_avg = np.mean(rewards, axis=1)
    return moving_avg

# %%
rmean_dict = {}
rstd_dict = {}

for model in models:
    res_list = res_groups[model]
    for idx, res in enumerate(res_list):
        rmv = ma(res['rewards'], m=400)
        if idx == 0:
            rs = rmv
        else:
            rs = np.vstack((rs, rmv))
    rmean_dict[model] = rs.mean(axis=0)
    rstd_dict[model] = rs.std(axis=0)

# %%
sns.set_style("white")
sns.set_palette("bright")
for idx, model in enumerate(models):
    rmean = rmean_dict[model] 
    rstd = rstd_dict[model] 
    x = np.arange(len(rmean))
    sns.lineplot(x=x, y=rmean, label=model_names[idx])
    plt.fill_between(x, rmean - rstd, rmean + rstd, alpha=0.1)
plt.ylabel("Reward")
plt.xlabel("Epoch (in thousand)")
plt.legend( loc="lower right")
plt.title('Training (self-play)')
plt.savefig('lc.pdf')
plt.show()

# %% [markdown]
# ## Part 2: Self-play scores
#
# SP score for each model. The mean and std are for differently-seeded agents. Each agent pair plays 100 games for sample.

# %%
for model in models:
    meanscore = np.diag(xp_groups[model]).mean()
    stdscore = np.diag(xp_groups[model]).std()
    print('{:.2}'.format(meanscore), '{:.2}'.format(stdscore), model, 'SP')
# Out:
# 0.85 0.017 FF SP
# 0.87 0.017 LSTM SP
# 0.87 0.025 Att1 SP
# 0.77 0.028 Att2 SP
# 0.75 0.05 Att3 SP

# %% [markdown]
# ### Sample a few games for each architecture
#
# In models except Att3, the conventions are not dicipherable. Which card to hint/play not only depend on the label on the relavent cards, but also seem to intricately depends on other cards in the hand as well.
#
# In Att3, they just hint the playable card one cluster, and the furtherest card in the other cluster.

# %%
from sample.sample import sample_games

game_num = 2
# Out:
# GPU not available, CPU used

# %%
model = 'FF'

p1 = res_groups[model][0]['p1']
p2 = res_groups[model][0]['p2']

sample_games(p1, p2, episodes=game_num, verbose=True)
# Out:
# ===== Game starts with handsize: 5, nlabl: 3, nlab2: 3 =====
# Playable hand is: 3A
# Agent 1 hand is: ['2A', '2B', '2C', '1C', '2A']
# Agent 2 hand is: ['3C', '2B', '2B', '3̲A', '3̲A']
# Agent 1 hints 2A @  0
# Agent 2 plays 3A @  4
# Final reward of game: 1.0
#
#
# ===== Game starts with handsize: 5, nlabl: 3, nlab2: 3 =====
# Playable hand is: 2C
# Agent 1 hand is: ['2̲C', '1A', '3B', '3C', '1A']
# Agent 2 hand is: ['1C', '1C', '2A', '2̲C', '3A']
# Agent 1 hints 3B @  2
# Agent 2 plays 2C @  3
# Final reward of game: 1.0
# array([1., 1.], dtype=float32)

# %%
model = 'Att3'

p1 = res_groups[model][4]['p1']
p2 = res_groups[model][4]['p2']

sample_games(p1, p2, episodes=game_num, verbose=True)
# Out:
# ===== Game starts with handsize: 5, nlabl: 3, nlab2: 3 =====
# Playable hand is: 3A
# Agent 1 hand is: ['2B', '1A', '3C', '1B', '3̲A']
# Agent 2 hand is: ['2C', '3̲A', '3C', '2C', '1A']
# Agent 1 hints 3A @  4
# Agent 2 plays 3A @  1
# Final reward of game: 1.0
#
#
# ===== Game starts with handsize: 5, nlabl: 3, nlab2: 3 =====
# Playable hand is: 3B
# Agent 1 hand is: ['2A', '2A', '3̲B', '3A', '2C']
# Agent 2 hand is: ['1C', '3C', '2B', '3̲B', '1B']
# Agent 1 hints 3B @  2
# Agent 2 plays 3B @  3
# Final reward of game: 1.0
# array([1., 1.], dtype=float32)

# %%
model = 'Att3'

aid =0

p1 = res_groups[model][aid]['p1']
p2 = res_groups[model][aid]['p2']

sample_games(p1, p2, episodes=game_num, verbose=True)
# Out:
# ===== Game starts with handsize: 5, nlabl: 3, nlab2: 3 =====
# Playable hand is: 3A
# Agent 1 hand is: ['3C', '2C', '2B', '2B', '1B']
# Agent 2 hand is: ['1C', '1A', '3B', '3̲A', '3̲A']
# Agent 1 hints 1B @  4
# Agent 2 plays 3A @  3
# Final reward of game: 1.0
#
#
# ===== Game starts with handsize: 5, nlabl: 3, nlab2: 3 =====
# Playable hand is: 3A
# Agent 1 hand is: ['3B', '3B', '3̲A', '2C', '3̲A']
# Agent 2 hand is: ['1C', '2B', '3̲A', '2C', '2A']
# Agent 1 hints 2C @  3
# Agent 2 plays 3A @  2
# Final reward of game: 1.0
# array([1., 1.], dtype=float32)

# %% [markdown]
# ## XP matrices

# %%
def arg_sort_xp(xpm):
    xpm = xpm.values
    xpm = xpm[:13,:13]
    idx = np.argsort(xpm[:,0])
    xpm = xpm[idx][:,idx]
    return xpm

ff = arg_sort_xp(xp_groups['FF'])
lstm = arg_sort_xp(xp_groups['LSTM'])
att1 = arg_sort_xp(xp_groups['Att1'])
att2 = arg_sort_xp(xp_groups['Att2'])
att3 = arg_sort_xp(xp_groups['Att3'])

# %%
def get_table_scores(mat):
    sp_score_mean, sp_score_std = np.mean(np.diag(mat)), np.sqrt(np.var(np.diag(mat)))
    off_diag = np.where(~np.eye(mat.shape[0],dtype=bool))
    xp_score_mean, xp_score_std = np.mean(mat[off_diag]), np.sqrt(np.var(mat[off_diag]))
    return sp_score_mean, sp_score_std, xp_score_mean, xp_score_std

clus = 5

print("Feed forward: ")
print(get_table_scores(ff))
print("LSTM: ")
print(get_table_scores(lstm))
print("Att1: ")
print(get_table_scores(att1))
print("Att2: ")
print(get_table_scores(att2))
print("Att3: ")
print(get_table_scores(att3))
print("Att3 cluster 1: ")
print(get_table_scores(att3[:clus,:clus]))
print("Att3 cluster 2: ")
print(get_table_scores(att3[clus:,clus:]))
# Out:
# Feed forward:
# (0.8516923097463754, 0.015958524081717065, 0.27330769354907364, 0.13381362107562858)
# LSTM:
# (0.872307694875277, 0.018594400487253755, 0.29543589867460424, 0.14547778009277304)
# Att1:
# (0.8673846171452448, 0.02680280518872309, 0.2742564113667378, 0.12411837078894919)
# Att2:
# (0.7784615388283362, 0.02154285837558548, 0.26107692400900984, 0.10105326947624214)
# Att3:
# (0.7563076890431918, 0.054743292794180554, 0.36858974267036104, 0.35052774890186533)
# Att3 cluster 1:
# (0.8199999928474426, 0.02386629064395467, 0.7705999970436096, 0.02295299171446037)
# Att3 cluster 2:
# (0.716499999165535, 0.01984313806206946, 0.7114285698958805, 0.03067272840650795)

# %%
fig, axs = plt.subplots(ncols=6, gridspec_kw=dict(width_ratios=[4,4,4,4,4,0.2]), figsize=(25,4.5))

cmap = "viridis"
# cmap = "rocket"

vmax = 1
vmin = 0

sns.heatmap(ff, cbar=False, ax=axs[0], cmap=cmap, vmax=vmax, vmin=vmin)
sns.heatmap(lstm, cbar=False, ax=axs[1], cmap=cmap, vmax=vmax, vmin=vmin)
sns.heatmap(att1, cbar=False, ax=axs[2], cmap=cmap, vmax=vmax, vmin=vmin)
sns.heatmap(att2, cbar=False, ax=axs[3], cmap=cmap, vmax=vmax, vmin=vmin)
sns.heatmap(att3, cbar=False, ax=axs[4], cmap=cmap, vmax=vmax, vmin=vmin)

fig.colorbar(axs[3].collections[0], cax=axs[5])

for i in range(5):
    axs[i].set_ylabel('Player 1: Hinter Agent')
    axs[i].set_xlabel('Player 2: Guesser Agent')
    axs[i].title.set_text(model_names[i])
    axs[i].xaxis.tick_top()

plt.savefig('xp_diff.pdf')
plt.show()

# %% [markdown]
# ## Marginal probabilities

# %%
mpt_att3_c = pd.read_csv('sample/marginal/mp_targethint_Att3-C_6_1000.csv', index_col=0)
mpt_att3_f = pd.read_csv('sample/marginal/mp_targethint_Att3-F_11_1000.csv', index_col=0)
mpt_ff = pd.read_csv('sample/marginal/mp_targethint_FF_20_1000.csv', index_col=0)
mpt_att1 = pd.read_csv('sample/marginal/mp_targethint_Att1_19_1000.csv', index_col=0)
mpt_att2 = pd.read_csv('sample/marginal/mp_targethint_Att2_19_1000.csv', index_col=0)
mpt_lstm = pd.read_csv('sample/marginal/mp_targethint_LSTM_20_1000.csv', index_col=0)



mph_att3_c = pd.read_csv('sample/marginal/mp_hintplay_Att3-C_6_1000.csv', index_col=0)
mph_att3_f = pd.read_csv('sample/marginal/mp_hintplay_Att3-F_11_1000.csv', index_col=0)
mph_ff = pd.read_csv('sample/marginal/mp_hintplay_FF_20_1000.csv', index_col=0)
mph_att1 = pd.read_csv('sample/marginal/mp_hintplay_Att1_19_1000.csv', index_col=0)
mph_att2 = pd.read_csv('sample/marginal/mp_hintplay_Att2_19_1000.csv', index_col=0)
mph_lstm = pd.read_csv('sample/marginal/mp_hintplay_LSTM_20_1000.csv', index_col=0)

# %%
fig, axs = plt.subplots(ncols=6, nrows=2, gridspec_kw=dict(width_ratios=[4,4,4,4,4,4,], height_ratios=[1,1]), figsize=(30,10))

#cmap = "YlGnBu"
cmap = "Blues"

sample_mp_agents = ['Feedforward', 'Recurrent', 'Att + O', 'Att + O + AO', 
                    'Att + O + AI: Cluster 1', 'Att + O+ AI: Cluster 2']

vmax = 0.5 
vmin = 0

sns.heatmap(mpt_ff, cbar=False, ax=axs[0][0], cmap=cmap, vmax=vmax, vmin=0)
sns.heatmap(mpt_lstm, cbar=False, ax=axs[0][1], cmap=cmap, vmax=vmax, vmin=0)
sns.heatmap(mpt_att1, cbar=False, ax=axs[0][2], cmap=cmap, vmax=vmax, vmin=0)
sns.heatmap(mpt_att2, cbar=False, ax=axs[0][3], cmap=cmap, vmax=vmax, vmin=0)
sns.heatmap(mpt_att3_c, cbar=False, ax=axs[0][4], cmap=cmap, vmax=vmax, vmin=0)
sns.heatmap(mpt_att3_f, cbar=False, ax=axs[0][5], cmap=cmap, vmax=vmax, vmin=0)


sns.heatmap(mph_ff, cbar=False, ax=axs[1][0], cmap=cmap, vmax=vmax, vmin=0)
sns.heatmap(mph_lstm, cbar=False, ax=axs[1][1], cmap=cmap, vmax=vmax, vmin=0)
sns.heatmap(mph_att1, cbar=False, ax=axs[1][2], cmap=cmap, vmax=vmax, vmin=0)
sns.heatmap(mph_att2, cbar=False, ax=axs[1][3], cmap=cmap, vmax=vmax, vmin=0)
sns.heatmap(mph_att3_c, cbar=False, ax=axs[1][4], cmap=cmap, vmax=vmax, vmin=0)
sns.heatmap(mph_att3_f, cbar=False, ax=axs[1][5], cmap=cmap, vmax=vmax, vmin=0)


fig.subplots_adjust(right=0.88)
cbar_ax = fig.add_axes([0.9, 0.15, 0.01, 0.7])
fig.colorbar(axs[0][4].collections[0], cax=cbar_ax)


for i in range(6):
    axs[0][i].set_ylabel('Target Card')
    axs[0][i].set_xlabel('Player 1 Hint Card')
    axs[0][i].title.set_text(sample_mp_agents[i])
    axs[0][i].xaxis.tick_top()
    
for i in range(6):
    axs[1][i].set_ylabel('Hint Card')
    axs[1][i].set_xlabel('Player 2 Guess Card')
    axs[1][i].xaxis.tick_top()

plt.savefig('mp.pdf')
plt.show()

# %% [markdown]
# ## Attention matrix

# %%
res_groups['Att3'][0]['p1'].policy_net.attn_head
# Out:
# Attention(
#   (q_linear): Linear(in_features=12, out_features=12, bias=True)
#   (k_linear): Linear(in_features=12, out_features=12, bias=True)
#   (v_linear): Linear(in_features=12, out_features=12, bias=True)
#   (norm_1): Norm()
#   (norm_2): Norm()
#   (dropout_1): Dropout(p=0.1, inplace=False)
#   (dropout_2): Dropout(p=0.1, inplace=False)
# )

# %%
player = 'p2'

for aid in range(12):
    if aid == 0:
        q = res_groups['Att3'][0][player].policy_net.attn_head.q_linear.weight.data.numpy()
        k = res_groups['Att3'][0][player].policy_net.attn_head.k_linear.weight.data.numpy()
        v = res_groups['Att3'][0][player].policy_net.attn_head.v_linear.weight.data.numpy()
    else:
        q += res_groups['Att3'][aid][player].policy_net.attn_head.q_linear.weight.data.numpy()
        k += res_groups['Att3'][aid][player].policy_net.attn_head.k_linear.weight.data.numpy()
        v += res_groups['Att3'][aid][player].policy_net.attn_head.v_linear.weight.data.numpy()

# %%
sns.heatmap(q, cbar=True, cmap=cmap)
plt.show()

# %%
sns.heatmap(k, cbar=True, cmap=cmap)
plt.show()

# %%
sns.heatmap(v, cbar=True, cmap=cmap)
plt.show()
